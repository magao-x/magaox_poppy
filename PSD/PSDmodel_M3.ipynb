# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
#load modules
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from astropy import units as u
from astropy.io import fits

# import personal code
from model_kit import psd_functions as psd
from model_kit import datafiles as dfx

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# this is here to accomodate the old version of calculating the avg psd
# but the new version opens up a fits file that already has all the data
class psd_avg_obj:
    def __init__(self, fitsfilename):
        fd = fits.open(fitsfilename)
        psd_data = fd[1].data
        self.k_radial = psd_data.k_radial / u.m
        self.psd_radial_cal = psd_data.psd_radial * u.m**2 * u.nm**2
        
        hdr = fd[0].header
        self.k_min = hdr['kmin']/u.m
        self.k_max = hdr['kmax']/u.m
        self.npix_diam = hdr['diam_pix']
        self.delta_k = hdr['delta_k']/u.m
        side = hdr['oversamp']
        self.psd_cal = np.zeros((side, side)) # filler for the pre-existing code
        
        self.rms_tot = hdr['rms_tot']*u.nm

# %%
# load the data
avg_psd = psd_avg_obj(fitsfilename='radial/psd_m3.fits')

# set initial conditions
opt_parms = {'ca' : 100,
             'ovs': 4096,
             'diam_100CA': 0.650*u.m, # not really useful but okay
             'surf_units': u.micron,
             'ring_width': 3,
             'kmid_ll': 100/u.m,
             'khigh_ll': 1000/u.m,
             'label': 'm3'}

# %%
# %%time
ist = [0, 100]
iend = ist[1:]
iend.append(len(avg_psd.k_radial)-1)
rms_sr = [0.05*u.nm, 0.37*u.nm]
psd_weight = [1.0, 1.0]
k_limit = [np.amin(avg_psd.k_radial)/10, np.amax(avg_psd.k_radial)*10]
surf_unit = (avg_psd.psd_radial_cal.unit * (avg_psd.k_radial.unit**2))**(0.5)
mdl_set=[]
x0 = [[1.0e-0, 1.0e-0, 1.0e-0, 1.0e-0],
      [1.0e-0, 1.0e-0, 1.0e-0, 1.0e-0]]
for j in range(0, len(ist)):
    mdl = psd.model_single(region_num=j)
    mdl.load_data(ind_range=[ist[j],iend[j]], psd_obj=avg_psd)
    mdl.calc_psd_parm(rms_sr=rms_sr[j], x0=x0[j])#, ratio_mode=False)
    mdl.calc_model_total(psd_weight=psd_weight[j], 
                         k_spacing=avg_psd.delta_k*0.2, 
                         k_limit=k_limit)
    mdl_set.append(mdl)

# model sum with a total refit
ms_refit = psd.model_combine(mdl_set=mdl_set, avg_psd=avg_psd)
ms_refit.calc_refit()
ms_refit.calc_error()
ms_refit.calc_psd_rms()
# Out:
# CPU times: user 11.3 s, sys: 488 ms, total: 11.8 s
# Wall time: 8.44 s

# %%
psd.plot_model2(mdl_set, ms_refit, avg_psd, opt_parms, psd_range=[2e1, 1e-6])

# %%
# set the spatial frequency regions based on the index values
k_start = []
k_end = []
for k in range(0, len(ist)):
    k_start.append(avg_psd.k_radial[ist[k]].value)
    k_end.append(avg_psd.k_radial[iend[k]].value)
k_start*=avg_psd.k_radial[0].unit
k_end*=avg_psd.k_radial[0].unit

# set the names
parm_name = 'psd_{0}'.format(opt_parms['label'])
weight_name = parm_name + '_weight'
rms_name = parm_name + '_rms'

# set the PSD dictionary values
psd_dict = {parm_name: ms_refit.psd_parm,
            weight_name: psd_weight,
            rms_name: avg_psd.rms_tot,
            'k_start': k_start,
            'k_end': k_end,
            'rms_mod': ms_refit.psd_rms_sum,
            'rms_err': ms_refit.error_rms,
            'k_range': ms_refit.k_radial_data,
            'err_data': ms_refit.error,
            'mdl_data': ms_refit.psd_radial_sum_data,
            'psd_data': ms_refit.psd_radial_data}

# save the dictionary as a .FITS table file
fits_filename = 'model_parameters/psd_parms_{0}.fits'.format(opt_parms['label'])
psd.psd_model_to_fits(psd_dict=psd_dict, opt_name=opt_parms['label'], 
                     fits_filename=fits_filename,
                     surf_unit=u.nm, lat_unit=u.m)

# %%
# this file doesn't exist anymore, so need to fill in the values separately later.
m3_hdr = fits.open('/home/jhen/XWCL/code/MagAOX/data/PSDflatSet1/M3_fitpsd.fits')[0].header

# setting the parameters
m3_alpha = m3_hdr['alpha']
m3_beta = m3_hdr['beta']*(m3_hdr['puplscal']**2)*(u.nm**2)/(u.m**(m3_alpha-2))
parm_pdr = [m3_alpha, m3_beta, 0.0*u.m, 0.0, 0.0*(u.m*u.nm)**2]
psd_pdr = psd.model_full(k=mdl_set[0].k_range, psd_parm=parm_pdr)
pdr_weight = [1.0]

# setting the rms value
pdr_rms = psd.calc_model_rms(psd_parm=[parm_pdr], psd_weight=pdr_weight, 
                             side=ms_refit.side, delta_k=ms_refit.delta_k,
                             k_tgt_lim=[ms_refit.k_min, ms_refit.k_max])

k_radial = m3.k_radial.value
psd_radial = m3.psd_radial_cal.value
k_range_mdl = mdl_set[0].k_range.value

plt.figure(figsize=[14,10],dpi=150)
gs = gridspec.GridSpec(ncols=1, nrows=2, height_ratios=[4,2])
ax0 = plt.subplot(gs[0])  
ax0.loglog(k_radial, psd_radial, 'k', linewidth=4, 
           label='Avg PSD (PTT, all steps)\nRMS={0:.4f}'.format(m3.rms_tot))
ax0.loglog(k_range_mdl, ms_refit.psd_radial_sum.value, 'r', linewidth=2.5, 
           label='Model sum, refit\nRMS={0:.4f}'.format(ms_refit.psd_rms_sum))
ax0.loglog(k_range_mdl, psd_pdr.value, 'c', linewidth=1.5, 
           label='PDR parameter\nRMS={0:.4f}'.format(pdr_rms))
ax0.set_xlim(left=np.amin(k_range_mdl)*0.8, right=np.amax(k_range_mdl)*1.2)
ax0.set_ylim(bottom=1e-5)
ax0.set_ylabel('PSD ({0})'.format(ms_refit.psd_radial_sum.unit), fontsize=15)
ax0.legend(prop={'size':12})#,loc='center left', bbox_to_anchor=(1, 0.5))
ax0.set_title('MagAO-X PSD modeling: FM {0}, {1}% CA'.format(opt_parms['label'],opt_parms['ca']),
             fontsize=20)

ax1 = plt.subplot(gs[1])
ax1.hlines(y=0, xmin=np.amin(k_range_mdl)*0.8, xmax=np.amax(k_range_mdl)*1.2, color='k', 
           label='Data reference')
ax1.semilogx(k_radial, ms_refit.error, 'r', 
             label='Model Error RMS={0:.4f}'.format(ms_refit.error_rms))
ax1.legend(prop={'size':12})
ax1.set_ylim(top=0.6, bottom=-0.6)
ax1.set_xlim(left=np.amin(k_range_mdl)*0.8, right=np.amax(k_range_mdl)*1.2)
ax1.set_ylabel('log10(model / measured)', fontsize=15)
ax1.set_xlabel('Spatial Frequency [{0}]'.format(ms_refit.k_radial_data.unit), fontsize=15)

plt.tight_layout()
# Out:
# /home/jhen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:39: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
